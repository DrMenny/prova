# %%
import pandas as pd

# %%
data = pd.read_csv('air_fare_train.csv')
#test = pd.read_csv('air_fare_test.csv')

# %%
data
# Out:
#        Activity Period                  Operating Airline  \
# 0               201201   United Airlines - Pre 07/01/2013
# 1               201204                  Hawaiian Airlines
# 2               201712                           Emirates
# 3               201411           KLM Royal Dutch Airlines
# 4               202002                    Delta Air Lines
# ...                ...                                ...
# 18537           201209                   SkyWest Airlines
# 18538           200910  Northwest Airlines (became Delta)
# 18539           201407                         Air Canada
# 18540           201801                      Swissport USA
# 18541           200810   United Airlines - Pre 07/01/2013
#
#       Operating Airline IATA Code                  Published Airline  \
# 0                              UA   United Airlines - Pre 07/01/2013
# 1                              HA                  Hawaiian Airlines
# ...

# %%
keys_to_take = ["Operating Airline", "Published Airline", "GEO Summary", "GEO Region", "Price Category Code"]
res = {"_".join(k.lower().split(" ")):v for k, v in data.items() if k in keys_to_take}
res
# Out:
# {'operating_airline': 0         United Airlines - Pre 07/01/2013
#  1                        Hawaiian Airlines
#  2                                 Emirates
#  3                 KLM Royal Dutch Airlines
#  4                          Delta Air Lines
#                         ...
#  18537                     SkyWest Airlines
#  18538    Northwest Airlines (became Delta)
#  18539                           Air Canada
#  18540                        Swissport USA
#  18541     United Airlines - Pre 07/01/2013
#  Name: Operating Airline, Length: 18542, dtype: object,
#  'published_airline': 0         United Airlines - Pre 07/01/2013
#  1                        Hawaiian Airlines
#  2                                 Emirates
#  3                 KLM Royal Dutch Airlines
#  4                          Delta Air Lines
#                         ...
#  18537                      Delta Air Lines
#  18538    Northwest Airlines (became Delta)
#  18539                           Air Canada
# ...

# %%
for x in data.items():
    print(x)
# Out:
# ('Activity Period', 0        201201
# 1        201204
# 2        201712
# 3        201411
# 4        202002
#           ...
# 18537    201209
# 18538    200910
# 18539    201407
# 18540    201801
# 18541    200810
# Name: Activity Period, Length: 18542, dtype: int64)
# ('Operating Airline', 0         United Airlines - Pre 07/01/2013
# 1                        Hawaiian Airlines
# 2                                 Emirates
# 3                 KLM Royal Dutch Airlines
# 4                          Delta Air Lines
#                        ...
# 18537                     SkyWest Airlines
# 18538    Northwest Airlines (became Delta)
# 18539                           Air Canada
# 18540                        Swissport USA
# 18541     United Airlines - Pre 07/01/2013
# Name: Operating Airline, Length: 18542, dtype: object)
# ('Operating Airline IATA Code', 0         UA
# 1         HA
# 2         EK
# 3         KL
# 4         DL
#         ...
# 18537     OO
# 18538     NW
# 18539     AC
# ...

# %%
res["target"] = int(data["Passenger Count"])
res["year"] = int(str(data['Activity Period'])[:4])
res["month"] = int(str(data['Activity Period'])[-2:])

return res

# %%
data.items()
# Out:
# <generator object DataFrame.items at 0x7fddd578bc80>

# %%
h_letters = []

for letter in "human":
    h_letters.append(letter)

h_letters
# Out:
# ['h', 'u', 'm', 'a', 'n']

# %%
h_letters = [letter for letter in "human"]

h_letter
# Out:
# ['h', 'u', 'm', 'a', 'n']

# %%
transposed = []
matrix = [[1,2,3,4],[5,6,7,8]]

# %%
for i in range(len(matrix[0])):
    transposed_row = []
    
    for row in matrix:
        transposed_row.append(row[i])
    
    transposed.append(transposed_row)
    
transposed
# Out:
# [[1, 5], [2, 6], [3, 7], [4, 8]]

# %%
matrix = [[1, 2], [3,4], [5,6], [7,8]]
transpose = [[row[i] for row in matrix] for i in range(2)]
print(transpose)
# Out:
# [[1, 3, 5, 7], [2, 4, 6, 8]]

# %%
transpose = [row[0] for row in matrix]
transpose
# Out:
# [1, 3, 5, 7]
